# %% [markdown]
# Q1. What is Object-Oriented Programming (OOP)?
# -  Object-Oriented Programming (OOP) is a programming paradigm that revolves around the concept of objects and classes. It’s a way to design and structure code by organizing data and behavior into reusable, modular units.
#
# Key Principles of OOP:
# 1. Encapsulation: Bundling data (attributes) and methods (functions) that operate on that data into a single unit, called a class or object.
# 2. Abstraction: Hiding internal implementation details and exposing only the necessary information to the outside world.
# 3. Inheritance: Creating new classes based on existing ones, inheriting their properties and behavior.
# 4. Polymorphism: The ability of an object to take on multiple forms, depending on the context in which it is used.
#
# Benefits of OOP:
# 1. Modularity: OOP promotes modular code that is easier to maintain, modify, and reuse.
# 2. Reusability: Classes and objects can be reused in different parts of the program or even in different projects.
# 3. Easier Debugging: With OOP, it's easier to identify and fix errors, as the code is organized into self-contained units.

# %% [markdown]
# Q2. What is a class in OOP?
# -  Class in OOP
# In Object-Oriented Programming (OOP), a class is a blueprint or template that defines the properties and behavior of an object. It's a fundamental concept in OOP that helps create objects with similar characteristics.
#
# Key Features of a Class:
# 1. Attributes (Data Members): A class defines the properties or attributes of an object, such as variables or data members.
# 2. Methods (Functions): A class defines the actions or methods that an object can perform, such as functions or procedures.
# 3. Constructor: A special method that initializes an object when it's created.
#
# Purpose of a Class:
# 1. Define Structure: A class defines the structure of an object, including its properties and behavior.
# 2. Create Objects: A class is used to create multiple objects with similar characteristics.
# 3. Encapsulate Data: A class encapsulates data and methods that operate on that data, promoting data hiding and abstraction.

# %%
#For Example

class Car:
    def __init__(self, color, model, year):
        self.color = color
        self.model = model
        self.year = year

    def start(self):
        print("The car is starting.")

    def accelerate(self):
        print("The car is accelerating.")

# %%
My_car = Car("Red", "Toyota", 2023)

# %%
My_car.start()
# Out:
# The car is starting.

# %%
My_car.accelerate()
# Out:
# The car is accelerating.

# %% [markdown]
# Q3. What is an object in OOP?
# -  Object in OOP
# In Object-Oriented Programming (OOP), an object is an instance of a class. It represents a real-world entity or concept and has its own set of attributes (data) and methods (functions).
#
# Key Features of an Object:
# 1. Attributes (Data): An object has its own set of attributes, which are used to store data.
# 2. Methods (Functions): An object has its own set of methods, which are used to perform actions.
# 3. Identity: Each object has its own unique identity, which distinguishes it from other objects.
# 4. State: An object has a state, which is defined by the values of its attributes.
# 5. Behavior: An object has behavior, which is defined by its methods.

# %% [markdown]
# Q4.  What is the difference between abstraction and encapsulation?
# -  Abstraction:
# - Definition: Abstraction is the process of exposing only the essential features of an object or system while hiding the internal details.
# - Purpose: Abstraction helps to reduce complexity by showing only the necessary information to the outside world.
# - Example: A car's accelerator pedal is an abstraction of the complex engine mechanics. You don't need to know how the engine works to use the pedal.
#
# Encapsulation:
# - Definition: Encapsulation is the process of bundling data (attributes) and methods (functions) that operate on that data into a single unit, called a class or object.
# - Purpose: Encapsulation helps to hide the internal implementation details of an object from the outside world and provides a controlled access to the data.
# - Example: A bank account object encapsulates the account balance and provides methods to deposit and withdraw money.

# %% [markdown]
# Q5.  What are dunder methods in Python?
# -   Dunder Methods in Python
# In Python, dunder methods (short for "double underscore" methods) are special methods that are surrounded by double underscores (__) on either side of the method name. These methods are also known as magic methods or special methods.
#
# Purpose of Dunder Methods:
# Dunder methods are used to define custom behavior for objects of a class. They are typically used for:
#
# 1. Operator overloading: Defining custom behavior for operators like +, -, *, etc.
# 2. Initialization and finalization: Defining custom behavior for object creation and destruction.
# 3. String representation: Defining custom string representations of objects.
# 4. Comparison and sorting: Defining custom comparison and sorting behavior.
#
# Examples of Dunder Methods:
# 1. __init__: Initializes an object when it's created.
# 2. __str__: Returns a string representation of an object.
# 3. __repr__: Returns a string representation of an object that's useful for debugging.
# 4. __add__: Defines custom behavior for the + operator.
# 5. __eq__: Defines custom behavior for the == operator.

# %% [markdown]
# Q6. Explain the concept of inheritance in OOP?
# -  Inheritance in OOP
# Inheritance is a fundamental concept in Object-Oriented Programming (OOP) that allows one class to inherit the properties and behavior of another class.
#
# Key Features of Inheritance:
# 1. Parent-Child Relationship: Inheritance creates a parent-child relationship between two classes, where the child class inherits the properties and behavior of the parent class.
# 2. Code Reusability: Inheritance promotes code reusability by allowing child classes to inherit common attributes and methods from the parent class.
# 3. Hierarchical Relationships: Inheritance helps to model hierarchical relationships between classes, where a child class is a specialized version of the parent class.
#
# Types of Inheritance:
# 1. Single Inheritance: A child class inherits from a single parent class.
# 2. Multiple Inheritance: A child class inherits from multiple parent classes.
# 3. Multilevel Inheritance: A child class inherits from a parent class that itself inherits from another parent class.
#
# Benefits of Inheritance:
# 1. Reduced Code Duplication: Inheritance helps to reduce code duplication by allowing child classes to inherit common attributes and methods from the parent class.
# 2. Improved Code Organization: Inheritance helps to organize code in a hierarchical manner, making it easier to understand and maintain.
# 3. Easier Maintenance: Inheritance makes it easier to modify or extend the behavior of a class without affecting other parts of the program.

# %% [markdown]
# Q7. What is polymorphism in OOP?
# -  Polymorphism in OOP
# Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that allows objects of different classes to be treated as objects of a common superclass.
#
# Key Features of Polymorphism:
# 1. Multiple Forms: Polymorphism allows objects to take on multiple forms, depending on the context in which they are used.
# 2. Method Overriding: Polymorphism allows subclasses to provide their own implementation of methods inherited from their superclass.
# 3. Method Overloading: Polymorphism allows multiple methods with the same name to be defined, but with different parameters.
#
# Types of Polymorphism:
# 1. Compile-time Polymorphism: Method overloading is an example of compile-time polymorphism, where the method to be called is determined at compile-time.
# 2. Runtime Polymorphism: Method overriding is an example of runtime polymorphism, where the method to be called is determined at runtime.
#
# Benefits of Polymorphism:
# 1. Increased Flexibility: Polymorphism allows for more flexibility in programming, as objects of different classes can be treated as objects of a common superclass.
# 2. Easier Maintenance: Polymorphism makes it easier to modify or extend the behavior of a class without affecting other parts of the program.
# 3. More Generic Code: Polymorphism allows for more generic code, which can work with objects of different classes.

# %% [markdown]
# Q8. How is encapsulation achieved in Python?
# -  Encapsulation in Python
# Encapsulation is achieved in Python through the use of classes and objects. Python provides several ways to encapsulate data and methods, including:
# (i)Public Attributes and Methods  (ii)Private Attributes and Methods  (iii) Protected Attributes and Methods

# %%
# for example

class BankAccount:
    def __init__(self, account_number, balance):
        self.__account_number = account_number  # Private attribute
        self._balance = balance  # Protected attribute

    def deposit(self, amount):
        self._balance += amount

    def get_balance(self):
        return self._balance

    def __update_account_number(self, new_account_number):  # Private method
        self.__account_number = new_account_number

# %%
account=BankAccount("123456789",1000)

# %%
account.deposit(500)

# %%
account.get_balance()
# Out:
# 1500

# %% [markdown]
# Q9.What is a constructor in Python?
# -  Constructor in Python
# In Python, a constructor is a special method that is automatically called when an object of a class is created. It is used to initialize the attributes of the class.
#
# __init__ Method
# The constructor in Python is defined using the __init__ method. This method is called when an object is created from a class, and it allows the class to initialize the attributes of the class.

# %%
#for example

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
person=Person("John",25)

# %%
person.name
# Out:
# 'John'

# %%
person.age
# Out:
# 25

# %% [markdown]
# Q10. What are class and static methods in Python?
# -  Class and Static Methods in Python
# In Python, you can define two types of methods that belong to a class rather than an instance: class methods and static methods.
#
# Class Methods
# - A class method is a method that is bound to the class rather than an instance.
# - It is defined using the @classmethod decorator.
# - The first parameter of a class method is a reference to the class itself, typically named cls.
#
# Static Methods
# - A static method is a method that belongs to a class rather than an instance.
# - It is defined using the @staticmethod decorator.
# - A static method does not take any implicit parameters (like self or cls).
#
# Key Differences
# 1. Binding: Class methods are bound to the class, while static methods are not bound to anything.
# 2. Parameters: Class methods take cls as the first parameter, while static methods do not take any implicit parameters.

# %% [markdown]
# Q11. What is method overloading in Python?
#
# -  Method Overloading in Python
# Method overloading is a feature in some programming languages that allows multiple methods with the same name to be defined, but with different parameters. However, Python does not support method overloading in the classical sense.

# %%
#for example
class Calculator:
    def calculate(self, a, b, operation="add"):
        if operation == "add":
            return a + b
        elif operation == "subtract":
            return a - b
        else:
            raise ValueError("Invalid operation")

# %%
cal=Calculator()

# %%
cal.calculate(5,3,)
# Out:
# 8

# %%
cal.calculate(5,3,"subtract")
# Out:
# 2

# %% [markdown]
# Q12. What is method overriding in OOP?
# -  Method Overriding in OOP
# Method overriding is a feature in Object-Oriented Programming (OOP) that allows a subclass to provide a specific implementation of a method that is already defined in its superclass.
# Purpose of Method Overriding
# Method overriding allows a subclass to:
#
# 1. Customize Behavior: Provide a specific implementation of a method that is tailored to its needs.
# 2. Extend Functionality: Add new functionality to a method while still maintaining the original behavior.
# 3. Override Default Behavior: Override the default behavior of a method in the superclass.

# %%
# for example

class Animal:
    def sound(self):
        print("The animal makes a sound.")

class Dog(Animal):
    def sound(self):
        print("The dog barks.")

class Cat(Animal):
    def sound(self):
        print("The cat meows.")

# %%
anl=Animal()

# %%
anl.sound()
# Out:
# The animal makes a sound.

# %%
Dg=Dog()

# %%
Dg.sound()
# Out:
# The dog barks.

# %%
cat=Cat()

# %%
cat.sound()
# Out:
# The cat meows.

# %% [markdown]
# Q13.  What is a property decorator in Python?
#
# -  Property Decorator in Python
# The @property decorator in Python is a way to implement getter, setter, and deleter functionality for attributes of a class. It allows you to customize access to instance data and provides a way to implement computed properties.

# %%
#For Example

class Person:
    def __init__(self, first_name, last_name):
        self._first_name = first_name
        self._last_name = last_name

    @property
    def full_name(self):
        return f'{self._first_name}  {self._last_name}'

# %%
pr=Person('Ajay','Yadav')

# %%
pr.full_name
# Out:
# 'Ajay  Yadav'

# %% [markdown]
# Q14.Why is polymorphism important in OOP?
# -  Importance of Polymorphism in OOP
# Polymorphism is a fundamental concept in Object-Oriented Programming (OOP) that allows for more flexibility, generic code, and easier maintenance. Here are some reasons why polymorphism is important:
#
# 1. Increased Flexibility: Polymorphism allows objects of different classes to be treated as objects of a common superclass, making it easier to write generic code that can work with different types of objects.
# 2. Generic Code: Polymorphism enables you to write code that can work with objects of different classes without knowing the specific class type at compile time.
# 3. Easier Maintenance: Polymorphism makes it easier to modify or extend the behavior of a class without affecting other parts of the program.
# 4. Improved Code Reusability: Polymorphism promotes code reusability by allowing you to write code that can work with different types of objects.
# 5. More Realistic Modeling: Polymorphism allows you to model real-world objects and systems more accurately, as objects can take on multiple forms and behaviors.

# %% [markdown]
# Q15.What is an abstract class in Python?
# -  Abstract Class in Python
# An abstract class in Python is a class that cannot be instantiated and is designed to be inherited by other classes. It provides a way to define a blueprint for other classes to follow and can include both abstract methods (methods without implementation) and concrete methods (methods with implementation).

# %%
#for Example

from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    def display(self):
        print("This is a shape")

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

# %%
cir=Circle(5)

# %%
cir.area()
# Out:
# 78.5

# %%
cir.display()
# Out:
# This is a shape

# %%
cir.radius
# Out:
# 5

# %% [markdown]
# Q16.  What are the advantages of OOP?
# -  Advantages of Object-Oriented Programming (OOP)
# Object-Oriented Programming (OOP) offers several advantages that make it a popular and effective programming paradigm. Here are some of the key benefits:
#
# 1. Modularity: OOP allows you to break down a program into smaller, independent modules (classes and objects) that can be developed, tested, and maintained separately.
# 2. Reusability: OOP enables code reusability through inheritance, polymorphism, and encapsulation, reducing code duplication and improving development efficiency.
# 3. Easier Maintenance: OOP makes it easier to modify or extend existing code without affecting other parts of the program, reducing maintenance costs and improving overall system reliability.
# 4. Improved Code Organization: OOP promotes a clear and organized code structure, making it easier to understand, modify, and maintain large programs.
# 5. Better Error Handling: OOP allows for more robust error handling through encapsulation and abstraction, reducing the likelihood of errors and improving overall system reliability.
# 6. Increased Flexibility: OOP enables you to write more flexible code that can adapt to changing requirements and new technologies.
# 7. Improved Readability: OOP promotes self-documenting code through the use of meaningful class and method names, making it easier for developers to understand and work with the code.
# 8. Easier Debugging: OOP makes it easier to identify and debug issues through the use of encapsulation and abstraction, reducing the complexity of debugging and improving overall development efficiency.

# %% [markdown]
# Q17. What is the difference between a class variable and an instance variable?
# -  Class Variables
# - Shared by all instances: Class variables are shared by all instances of a class.
# - Defined at the class level: Class variables are defined at the class level, outside of any method.
# - Accessed using the class name: Class variables can be accessed using the class name.
#
# Instance Variables
# - Unique to each instance: Instance variables are unique to each instance of a class.
# - Defined at the instance level: Instance variables are defined at the instance level, typically inside the __init__ method.
# - Accessed using the instance name: Instance variables are accessed using the instance name.

# %% [markdown]
# Q18. What is multiple inheritance in Python?
# -  Multiple Inheritance in Python
# Multiple inheritance is a feature in Python that allows a class to inherit properties and methods from more than one superclass. This means that a subclass can inherit the attributes and methods of multiple parent classes.

# %%
#for example
class Animal:
    def eat(self):
        print("The animal eats")

class Mammal:
    def sleep(self):
        print("The mammal sleeps")

class Dog(Animal, Mammal):
    def bark(self):
        print("The dog barks")

# %%
my_dog=Dog()

# %%
my_dog.bark()
# Out:
# The dog barks

# %%
my_dog.eat()
# Out:
# The animal eats

# %%
my_dog.sleep()
# Out:
# The mammal sleeps

# %% [markdown]
# Q19.  Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python?
# -  __str__ Method
# - Purpose: The __str__ method returns a string representation of an object that is intended to be human-readable.
# - Use cases: The __str__ method is used when you want to display an object in a user-friendly way, such as in a print statement or a GUI application.
# - Return value: The __str__ method should return a string that is easy to read and understand.
#
# __repr__ Method
# - Purpose: The __repr__ method returns a string representation of an object that is intended to be a valid Python expression.
# - Use cases: The __repr__ method is used when you want to represent an object in a way that can be used to recreate the object, such as in debugging or logging.
# - Return value: The __repr__ method should return a string that is a valid Python expression.

# %%
#for Example

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} is {self.age} years old"

    def __repr__(self):
        return f"Person(name='{self.name}', age={self.age})"

# %%
person = Person("John", 30)

# %%
person
# Out:
# Person(name='John', age=30)

# %%
print(repr(person))
# Out:
# Person(name='John', age=30)

# %%
print(str(person))
# Out:
# John is 30 years old

# %% [markdown]
# Q20. What is the significance of the ‘super()’ function in Python?
# -  super() Function in Python
# The super() function in Python is used to access the methods and properties of a parent class (also known as a superclass) from a child class (also known as a subclass).
#
# Purpose
# The super() function allows you to:
#
# 1. Call parent class methods: You can use super() to call methods of the parent class from the child class.
# 2. Override methods: You can use super() to override methods of the parent class in the child class.
# 3. Access parent class properties: You can use super() to access properties of the parent class from the child class.

# %%
# for example
class Animal:
    def __init__(self, name):
        self.name = name

    def sound(self):
        print("The animal makes a sound")

class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

    def sound(self):
        super().sound()
        print("The dog barks")

# %%
my_dog=Dog('poki',"Labrador")

# %%
my_dog.sound()
# Out:
# The animal makes a sound
# The dog barks

# %% [markdown]
# Q21.What is the significance of the __del__ method in Python?
# -  __del__ Method in Python
# The __del__ method in Python is a special method that is called when an object is about to be destroyed. This method is also known as a finalizer or a destructor.
#
# Purpose
# The __del__ method is used to:
#
# 1. Release resources: Release any system resources, such as file handles or network connections, that the object is using.
# 2. Clean up: Perform any necessary cleanup actions, such as deleting temporary files or releasing locks.
# 3. Finalize object state: Finalize the object's state before it is destroyed.

# %%
#For example

class FileHandler:
    def __init__(self, filename):
        self.filename = filename
        self.file = open(filename, 'w')

    def __del__(self):
        self.file.close()
        print(f"File {self.filename} closed")

# %%
file_handler = FileHandler("example.txt")
del file_handler
# Out:
# File example.txt closed

# %% [markdown]
# Q22. What is the difference between @staticmethod and @classmethod in Python?
# -  @staticmethod vs @classmethod in Python
# In Python, @staticmethod and @classmethod are two types of decorators that can be used to define methods in a class. While both decorators allow you to define methods that can be called without creating an instance of the class, there are key differences between them.
#
# @staticmethod
# - No access to class or instance: A static method has no access to the class or instance, and is essentially a function that belongs to the class's namespace.
# - No self or cls parameter: A static method does not take a self or cls parameter.
# - Use cases: Static methods are useful when you want to group related functionality together, but don't need to access the class or instance.
#
# @classmethod
# - Access to class: A class method has access to the class, and can use the class's attributes and methods.
# - cls parameter: A class method takes a cls parameter, which refers to the class itself.
# - Use cases: Class methods are useful when you want to define alternative constructors or methods that operate on the class level.

# %% [markdown]
# Q23.  How does polymorphism work in Python with inheritance?
# -  Polymorphism with Inheritance in Python
# Polymorphism is a fundamental concept in object-oriented programming that allows objects of different classes to be treated as objects of a common superclass. In Python, polymorphism works seamlessly with inheritance, enabling you to write more flexible and generic code.

# %%
#For exp.

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

def calculate_area(shape):
    return shape.area()

# %%
cir=Circle(5)
rect=Rectangle(4,5)

# %%
print(calculate_area(cir))
# Out:
# 78.5

# %%
print(calculate_area(rect))
# Out:
# 20

# %% [markdown]
# Q24.  What is method chaining in Python OOP?
# -  Method Chaining in Python OOP
# Method chaining is a programming technique in Python where multiple methods are called on the same object in a single line of code. This is achieved by having each method return the object itself, allowing the next method to be called on the same object.

# %%
#for exmp.

class Person:
    def __init__(self, name):
        self.name = name

    def set_age(self, age):
        self.age = age
        return self

    def set_city(self, city):
        self.city = city
        return self

    def display_info(self):
        print(f"Name: {self.name}, Age: {self.age}, City: {self.city}")

# %%
person = Person("John")
person.set_age(30).set_city("New York").display_info()
# Out:
# Name: John, Age: 30, City: New York

# %% [markdown]
# Q25.What is the purpose of the __call__ method in Python?
#
# -  __call__ Method in Python
# The __call__ method in Python is a special method that allows an instance of a class to be called as a function. This method is invoked when an object is called using parentheses ().
#
# Purpose
# The __call__ method is used to:
#
# 1. Make instances callable: By defining the __call__ method, you can make instances of a class callable, allowing them to behave like functions.
# 2. Implement function-like behavior: The __call__ method enables you to implement function-like behavior in a class, making it possible to pass instances around like functions.

# %%
#for exmp

class Counter:
    def __init__(self):
        self.count = 0

    def __call__(self):
        self.count += 1
        return self.count

# %%
counter = Counter()
print(counter())
print(counter())
print(counter())
# Out:
# 1
# 2
# 3

# %% [markdown]
# # Practical Qut
#
# Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".?

# %%
#Ans

class Animal:
    def speak(self):
        print("The animal speaks")

class Dog(Animal):
    def speak(self):
        print("barks")

# %%
an=Animal()
dg=Dog()

# %%
dg.speak()
# Out:
# barks

# %% [markdown]
# Q2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.?

# %%
#ans

from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass


class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius**2

class Rectangle(Shape):
     def __init__(self,w, h):
         self.w=w
         self.h=h
     def area(self):
         return self.w*self.h

# %%
cir=Circle(5)

# %%
rect=Rectangle(4,5)

# %%
cir.area()
# Out:
# 78.5

# %%
rect.area()
# Out:
# 20

# %% [markdown]
# Q3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.?

# %%
#Ans.

class Vehicle:
    def __init__(self, type):
        self.type = type
    def display_info(self):
        print(f"Type: {self.type}")

class Car(Vehicle):
    def __init__(self, type, color):
        super().__init__(type)
        self.color = color
    def display_info(self):
        super().display_info()
        print(f"Color: {self.color}")
class ElectricCar(Car):
    def __init__(self, type, color, battery):
        super().__init__(type, color)
        self.battery = battery

    def display_info(self):
        super().display_info()
        print(f"Battery: {self.battery}kwh")

# %%
elec=ElectricCar('car','red','5000')

# %%
elec.battery
# Out:
# '5000'

# %%
elec.display_info()
# Out:
# Type: car
# Color: red
# Battery: 5000kwh

# %%
# Q4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
#Sparrow and Penguin that override the fly() method.


# Base class Bird
class Bird:
    def fly(self):
        print("The bird is flying.")

# Derived class Sparrow
class Sparrow(Bird):
    def fly(self):
        print("The sparrow is flying swiftly.")

# Derived class Penguin
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly. They swim instead.")

# %%
# Function to demonstrate polymorphism
def make_bird_fly(bird):
    bird.fly()

# %%
sp=Sparrow()

# %%
pe=Penguin()

# %%
make_bird_fly(sp)
# Out:
# The sparrow is flying swiftly.

# %%
make_bird_fly(pe)
# Out:
# Penguins cannot fly. They swim instead.

# %%
# Q5 . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
#balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, balance):
        self.__balance = balance
    def deposit(self, amount):
        self.__balance += amount
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")
    def check_balance(self):
        return self.__balance

# %%
ban=BankAccount(1000)

# %%
ban.deposit(500)

# %%
ban.check_balance()
# Out:
# 1500

# %%
ban.withdraw(2000)
# Out:
# Insufficient balance

# %%
ban.withdraw(1200)

# %%
#Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("The instrument is playing.")

class Guitar(Instrument):
    def play(self):
        print("The guitar is playing.")

class Piano(Instrument):
    def play(self):
        print("The piano is playing.")

def play_instruments(instruments):
         instruments.play()

# %%
guit=Guitar()

# %%
pia=Piano()

# %%
play_instruments(guit)
# Out:
# The guitar is playing.

# %%
play_instruments(pia)
# Out:
# The piano is playing.

# %%
# Q7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.



class MathOperations:
    @classmethod
    def add_numbers(cls, num1, num2):
        return num1 + num2

    @staticmethod
    def subtract_numbers(num1, num2):
        return num1 - num2

# %%
Add= MathOperations.add_numbers(5,6)

# %%
print(Add)
# Out:
# 11

# %%
sub=MathOperations.subtract_numbers(10,5)

# %%
print(sub)
# Out:
# 5

# %%
#Q8 Implement a class Person with a class method to count the total number of persons created?


class Person:
    total_persons = 0

    def __init__(self, name, age):
        self.name = name
        self.age = age
        Person.total_persons += 1

    @classmethod
    def count_persons(cls):
        return cls.total_persons

# %%
p1=Person('ajay',30)
p2=Person('sumesh',32)
p3=Person('shakil',35)

# %%
total_persons=Person.count_persons()

# %%
print(total_persons)
# Out:
# 3

# %%
#Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".



class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero")
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return (f"{self.numerator}/{self.denominator}")

# %%
fra=Fraction(5,6)

# %%
print(fra)
# Out:
# 5/6

# %%
#Q10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
#  vectors.?


class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# %%
vect1=Vector(1,2)
vect2=Vector(3,4)
total_vect=(vect1+vect2)

# %%
print(total_vect)
# Out:
# (4, 6)

# %%
#Q11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."


class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
per=Person('ajay',30)

# %%
per.greet()
# Out:
# Hello, my name is ajay and I am 30 years old.

# %%
#Q12 Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades



class Student:
    def __init__(self, name, grades=None):
        self.name = name
        self.grades = grades if grades is not None else []

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

# %%
stud=Student('ajay',[1,2,3,4,5])

# %%
stud.average_grade()
# Out:
# 3.0

# %%
#Q14.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.


class Rectangle:
    def __init__(self, width=0, height=0):
        self.width = width
        self.height = height

    def set_dimensions(self, width, height):
        if width < 0 or height < 0:
            raise ValueError("Width and height cannot be negative")
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

# %%
rect=Rectangle()

# %%
rect.set_dimensions(2,4)

# %%
rect.area()
# Out:
# 8

# %%
#Q14.  Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.


class Employee:
    def __init__(self, name, hourly_rate):
        self.name = name
        self.hourly_rate = hourly_rate
        self.hours_worked = 0

    def log_hours(self, hours):
        self.hours_worked += hours

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hourly_rate, bonus):
        super().__init__(name, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# %%
emp=Employee('ajay',50)
emp.log_hours(120)
emp.calculate_salary()
# Out:
# 6000

# %%
man=Manager('ajay',50,10000)
man.log_hours(120)
man.calculate_salary()
# Out:
# 16000

# %%
#Q15.  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# %%
prod=Product('pen',10,2)

# %%
prod.total_price()
# Out:
# 20

# %%
# Q16.Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

from abc import ABC ,abstractmethod

class Animal(ABC):
    @abc.abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

# %%
cow=Cow()
sheep=Sheep()

# %%
cow.sound()
# Out:
# 'Moo'

# %%
sheep.sound()
# Out:
# 'Baa'

# %%
#Q17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

# %%
book=Book('the monkey','johan', 2008)

# %%
print (book.get_book_info())
# Out:
# 'the monkey' by johan, published in 2008

# %%
# Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

# %%
house=House('india',500000)

# %%
mansion=Mansion('india',500000,5)

# %%
mansion.number_of_rooms
# Out:
# 5

# %%
mansion.price
# Out:
# 500000
